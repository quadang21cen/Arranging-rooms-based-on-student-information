# %%
from typing_extensions import Self
from cv2 import SimpleBlobDetector_Params
import pandas as pd
from pip import main
from scipy.spatial.distance import cosine
import numpy as np
from sklearn import preprocessing
from NLP.Bag_Of_Words.Bag_of_Words_model import Bag_Of_Word
from NLP.Doc2Vec.Doc2Vec_model import Doc2Vec_Class
from NLP.TF_IDF.TF_IDF_model import TF_IDF_class

class RS:

    def __init__(self) -> None:
        self.features = ["Timestamp", "Name", "Sex", "Hometown", "Major", "Bio_personality", "food_drink", "hobby_interests",
                             "smoking", "refer_roommate", "Cleanliess", "Privacy", "Unnamed"]
        self.data = pd.read_csv('NLP\\Student_Ins.csv')
        self.data.columns = self.features
        self.all_user = self.data.iloc[:,:1].to_numpy().flatten()
        self.SIM_matrix = pd.DataFrame(index=self.all_user,columns=self.all_user)
        self.save_folder_doc2vec = None

    def corr_cosine(self, util_matrix):
        SIM_matrix = pd.DataFrame(index=self.all_user,columns=self.all_user)
        for i in range(0,util_matrix.__len__()):
            for j in range(0,util_matrix.__len__()):
                SIM_matrix.iloc[i][j] = cosine(util_matrix.iloc[i,1:].to_numpy(),util_matrix.iloc[j,1:].to_numpy())
        return SIM_matrix

    def corr_euclidean(self, util_matrix):
        SIM_matrix = pd.DataFrame(index=self.all_user,columns=self.all_user)
        for i in range(0,util_matrix.__len__()):
            for j in range(0,util_matrix.__len__()):
                SIM_matrix.iloc[i][j] = np.linalg.norm(util_matrix.iloc[i,1:].to_numpy() - util_matrix.iloc[j,1:].to_numpy())
        return SIM_matrix
        
    def compute_all_corr():
        pass
    def vectorize_BOW(self, features):
        BOW = Bag_Of_Word()
        for feature in features:
            self.data[feature] = BOW.text2vec(self.data[feature])
    def vectorize_TF_IDF_on_BOW(self, features):
        TF_IDF_instance = TF_IDF_class()
        BOW = Bag_Of_Word()
        for feature in features:
            self.data[feature] = TF_IDF_instance.text2vec(self.data[feature])
    def train_Doc2Vec_to_vector(self, features, save_folder, vector_size = 100, window = 2, epoch = 100):
        self.save_folder_doc2vec = save_folder
        doc_2_vec = Doc2Vec_Class()
        df = self.data
        self.doc2vec_instance = doc_2_vec.train(df = df, feature_list=features, save_folder = save_folder, vector_size=vector_size, window=window, epoch=epoch)
        for feature in features:
            self.data[feature] = doc_2_vec.load_to_matrix(save_folder+"/"+str(feature))
#     def cor_doc2vec(self, load_file, col):
#         doc_2_vec_2 = Doc2Vec_Class()
#         data = self.data[col]
#         x = data.values
#         #min_max_scaler = preprocessing.MinMaxScaler()
#         #x_scaled = min_max_scaler.fit_transform(x)
#         data = pd.DataFrame(x)
#         SIM_matrix = pd.DataFrame(index=self.all_user,columns=self.all_user)
#         for feature in col:
#             load_file = self.save_folder_doc2vec+"/"+str(feature)
#             for i in range(0,data.__len__()):
#                 for j in range(0,data.__len__()):
#                     SIM_matrix.iloc[i][j] = doc_2_vec_2.compare_two_unknown_docs(load_file, x.iloc[i,1:], x.iloc[j,1:])
#        return SIM_matrix
    def corr_matrix(self,col):
        data = self.data[col]
        x = data.values
        min_max_scaler = preprocessing.MinMaxScaler()
        x_scaled = min_max_scaler.fit_transform(x)
        data = pd.DataFrame(x_scaled)
        self.corr_euclidean(data)
        return self.corr_euclidean(data)

# %%
if __name__ == "__main__":
   class_RS = RS()
   #class_RS.vectorize_BOW(["Bio_personality", "food_drink", "hobby_interests"])
   #class_RS.vectorize_TF_IDF(["Bio_personality", "food_drink", "hobby_interests"])
   class_RS.train_Doc2Vec_to_vector(features = ["Bio_personality", "food_drink", "hobby_interests"], save_folder = "test")
   #print(class_RS.cor_doc2vec(load_file = "test", col = ["Bio_personality", "food_drink", "hobby_interests"]))
   print(class_RS.corr_matrix(["Bio_personality", "food_drink", "hobby_interests"]))
# Out:
# FINISH... Bio_personality
# Finish in--- 3.13702130317688 seconds ---
# FINISH... food_drink
# Finish in--- 5.918497323989868 seconds ---
# FINISH... hobby_interests
# Finish in--- 8.541576623916626 seconds ---
#                              2022/09/26 11:20:45 am GMT+7  \
# 2022/09/26 11:20:45 am GMT+7                          0.0
# 2022/09/26 11:27:35 am GMT+7                     0.332518
# 2022/09/26 11:40:18 am GMT+7                     0.415456
# 2022/09/26 11:47:23 am GMT+7                     0.339779
# 2022/09/26 12:29:57 pm GMT+7                      0.15741
# ...                                                   ...
# 2022/10/24 11:28:30 pm GMT+7                     0.251172
# 2022/10/24 11:39:00 pm GMT+7                     0.370678
# 2022/10/24 11:50:07 pm GMT+7                     0.198719
# 2022/10/25 12:06:05 am GMT+7                     0.290695
# 2022/10/25 7:40:27 pm GMT+7                      0.291818
#
#                              2022/09/26 11:27:35 am GMT+7  \
# 2022/09/26 11:20:45 am GMT+7                     0.332518
# 2022/09/26 11:27:35 am GMT+7                          0.0
# 2022/09/26 11:40:18 am GMT+7                     0.346721
# 2022/09/26 11:47:23 am GMT+7                     0.374311
# 2022/09/26 12:29:57 pm GMT+7                     0.259256
# ...                                                   ...
# 2022/10/24 11:28:30 pm GMT+7                     0.089845
# 2022/10/24 11:39:00 pm GMT+7                     0.197906
# 2022/10/24 11:50:07 pm GMT+7                     0.183684
# 2022/10/25 12:06:05 am GMT+7                     0.119405
# 2022/10/25 7:40:27 pm GMT+7                      0.139523
#
#                              2022/09/26 11:40:18 am GMT+7  \
# 2022/09/26 11:20:45 am GMT+7                     0.415456
# 2022/09/26 11:27:35 am GMT+7                     0.346721
# 2022/09/26 11:40:18 am GMT+7                          0.0
# 2022/09/26 11:47:23 am GMT+7                     0.117784
# 2022/09/26 12:29:57 pm GMT+7                     0.476828
# ...                                                   ...
# 2022/10/24 11:28:30 pm GMT+7                     0.368604
# 2022/10/24 11:39:00 pm GMT+7                     0.536982
# 2022/10/24 11:50:07 pm GMT+7                     0.435515
# 2022/10/25 12:06:05 am GMT+7                     0.234182
# 2022/10/25 7:40:27 pm GMT+7                      0.458059
#
#                              2022/09/26 11:47:23 am GMT+7  \
# 2022/09/26 11:20:45 am GMT+7                     0.339779
# 2022/09/26 11:27:35 am GMT+7                     0.374311
# 2022/09/26 11:40:18 am GMT+7                     0.117784
# 2022/09/26 11:47:23 am GMT+7                          0.0
# 2022/09/26 12:29:57 pm GMT+7                     0.434595
# ...                                                   ...
# 2022/10/24 11:28:30 pm GMT+7                     0.367425
# 2022/10/24 11:39:00 pm GMT+7                     0.543669
# 2022/10/24 11:50:07 pm GMT+7                     0.411144
# 2022/10/25 12:06:05 am GMT+7                     0.255058
# 2022/10/25 7:40:27 pm GMT+7                      0.457043
#
#                              2022/09/26 12:29:57 pm GMT+7  \
# 2022/09/26 11:20:45 am GMT+7